# %%
from sklearn.metrics import r2_score

# Sample data
y_true = [10, 20, 30, 40]  # Actual values
y_pred = [12, 18, 33, 38]  # Predicted values

# Calculate R-squared
r2 = r2_score(y_true, y_pred)
print(f"R-squared: {r2:.4f}")

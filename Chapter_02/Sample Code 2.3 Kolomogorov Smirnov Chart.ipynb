# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
score_thresholds = np.arange(0.1, 1.0, 0.1)
cumulative_positive = [5, 15, 30, 50, 70, 85, 95, 98, 100]
cumulative_negative = [20, 40, 55, 70, 85, 95, 98, 99, 100]
ks_statistic = [15, 25, 25, 20, 15, 10, 3, 1, 0]

# KS Chart
plt.figure(figsize=(10, 5))
plt.plot(score_thresholds, cumulative_positive, marker=‘o’, label=‘Cumulative % Positive Class’)
plt.plot(score_thresholds, cumulative_negative, marker=‘o’, label=‘Cumulative % Negative Class’)
plt.fill_between(score_thresholds, cumulative_positive, cumulative_negative, color=‘lightblue’, alpha=0.5)
plt.axvline(x=0.2, color=‘r’, linestyle=‘--’, label=f’KS Statistic = 25% at threshold 0.2’)
plt.title(‘Kolmogorov-Smirnov (KS) Chart’)
plt.xlabel(‘Score Threshold’)
plt.ylabel(‘Cumulative Percentage’)
plt.legend()
plt.grid()
plt.show()
# Lift Chart
plt.figure(figsize=(10, 5))
plt.plot(population, lift, marker=‘o’, label=‘Model’)
plt.axhline(y=1, color=‘r’, linestyle=‘--’, label=‘Random’)
plt.title(‘Lift Chart’)
plt.xlabel(‘Cumulative % Population’)
plt.ylabel(‘Lift’)
plt.legend()
plt.grid()
plt.show()

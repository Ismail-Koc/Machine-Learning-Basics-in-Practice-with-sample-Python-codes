# %%
# !sudo apt install espeak # install espeak text to speech engine to support pyttsx3
# !pip install pyttsx3  # Installing the pyttsx3 module.
import pyttsx3

engine = pyttsx3.init()
engine.say("Hello, welcome to NLP!")
engine.runAndWait()
